# %%
import requests
import pandas as pd

# API key de twitch
api_key = ''
url = ''

# parametres
params = {
    'key': api_key,      
    'page_size': 50,     
    'ordering': '-added', # Trier par date d'ajout (les plus récents en premier)
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()

    # extraction des datas
    data = []
